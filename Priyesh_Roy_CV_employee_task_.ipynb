# %% [markdown]
# *   I have developed the algorithm to detect the shade of a person’s teeth from the image and bifurcate into 5 grade categories (say, A, B, C, D and E, where A is best tooth white and E is most yellow teeth as per the given instruction.
# *   I have used a open source data sets and annotation it with the help of an annotation tool CVAT in five categories A,B,C, D and E based on warmness of yellow.
# *   I have used a total no. of images =784
#     * No. of images in the training set = 639
#     * No. of images in the validation set=100
#     * No. of images in the test set = 45
# *   I have trained the yolov8 model with the help of training data set and validate. and testing by the help of best.pt fille.
# *   Saved all the training results in runs/detect/train4 folder. and the tests images saved in runs/detect/predict4 folder.

# %%
from google.colab import drive  # for drive mounting
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Teeth
# Out:
# /content/drive/MyDrive/Teeth

# %%
ROOT_DIR = "/content/drive/MyDrive/Teeth"

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8n.yaml")  # for build a new model

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "google_colab_config.yaml"), epochs=200)  # train the model
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !scp -r /content/runs '/content/drive/MyDrive/Teeth'

# %%
from PIL import Image
import cv2

model = YOLO("/content/drive/MyDrive/Teeth/runs/detect/train4/weights/best.pt")
## from PIL
for i in range(1,46):  # for reading the test images
  adds='/content/drive/MyDrive/Teeth/data/test/test_data/'+str(i)+'.jpeg'
  im1 = Image.open(adds)
  results = model.predict(source=im1, save=True)  # save plotted images
## from list of PIL/ndarray
  results = model.predict(im1)  # The Results saved to runs/detect/predict4
# Out:
# 0: 448x640 1 C, 65.7ms
# Speed: 2.4ms preprocess, 65.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict4
#
# 0: 448x640 1 C, 6.0ms
# Speed: 1.8ms preprocess, 6.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 256x640 1 A, 56.7ms
# Speed: 1.0ms preprocess, 56.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict4
#
# 0: 256x640 1 A, 5.7ms
# Speed: 1.0ms preprocess, 5.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 448x640 1 C, 6.6ms
# Speed: 2.6ms preprocess, 6.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict4
#
# 0: 448x640 1 C, 6.0ms
# Speed: 1.6ms preprocess, 6.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 448x640 1 A, 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# ...
